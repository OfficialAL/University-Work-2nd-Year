# %%
# %load_ext sql

# %%
# %reload_ext sql

# %%
# %sql sqlite:///sql-murder-mystery.db

# %%
# %sql select * from person order by name limit 10
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(49350, 'Aaron Brunken', 384559, 3734, 'Fourteen Mile Way', '648235164'),
#  (96053, 'Aaron Elery', 552786, 2225, 'Castle Rd', '734477633'),
#  (86834, 'Aaron Larcher', 338012, 356, 'Harwalt Way', '662734103'),
#  (71064, 'Aaron Reitler', 838065, 2939, 'Cooke Ave', '591644629'),
#  (80579, 'Abbey Staniec', 785801, 2379, 'Pipers Glen Way', '193845734'),
#  (77941, 'Abbie Olano', 200795, 273, 'Spratt Hall Dr', '369146819'),
#  (23413, 'Abbie Palmitessa', 307960, 3341, 'South Marble Ave', '628802294'),
#  (57905, 'Abby Haddick', 234553, 2816, 'Tatton Rd', '381067100'),
#  (73835, 'Abdul Heinzen', 463494, 1630, 'Wegg Rd', '136717418'),
#  (45525, 'Abdul Lachowsky', 708058, 2769, 'Dock Hollow Circle', '489369460')]

# %%
# %sql select * from person  order by name desc limit 10
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(63255, 'Zulema Luescher', 664031, 230, 'Colvin Run St', '869505584'),
#  (68204, 'Zula Brisbin', 702740, 1424, 'Grasdene Blvd', '585404403'),
#  (59504, 'Zoraida Stakemann', 412588, 628, 'Molton Dr', '537075483'),
#  (57987, 'Zoraida Peroni', 829852, 1874, 'Coyote Ridge Blvd', '774401885'),
#  (95979, 'Zora Santio', 441152, 2265, 'Tee Circle', '899549970'),
#  (36394, 'Zora Lowney', 268935, 3356, 'Beauty Beach Dr', '504908833'),
#  (25829, 'Zona Langlands', 544406, 2155, 'Roda Rd', '191275353'),
#  (57352, 'Zoila Sleeth', 963486, 2513, 'Rodonovan Way', '446748604'),
#  (32789, 'Zoila Labrune', 147534, 954, 'Bleecker Way', '663848561'),
#  (98102, 'Zoila Flair', 482301, 3962, 'Dalveen Ave', '607133357')]

# %%
# %sql select count(*) from person
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(10011,)]

# %%
# %sql select max(height) from drivers_license
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(84,)]

# %%
# %sql select min(age) from drivers_license
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(18,)]

# %%
# %sql select avg(age) from drivers_license
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(53.18926751274108,)]

# %%
# %sql select sum(age) from drivers_license
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(532265,)]

# %%
# %sql select distinct type from crime_scene_report
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('robbery',),
#  ('murder',),
#  ('theft',),
#  ('fraud',),
#  ('arson',),
#  ('bribery',),
#  ('assault',),
#  ('smuggling',),
#  ('blackmail',)]

# %%
# %sql select * from crime_scene_report where type = 'fraud'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(20180115, 'fraud', 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do\n            eiusmod tempor incididunt ut labore et dolore magna aliqua.', 'Seattle'),
#  (20170101, 'fraud', 'forgotten to ask.’\n', 'Long Beach'),
#  (20170101, 'fraud', 'Alice did not wish to offend the Dormouse again, so she began very\n', 'Oceanside'),
#  (20170109, 'fraud', 'his fan and gloves--that is, if I can find them.’ As she said this, she\n', 'North Port'),
#  (20170113, 'fraud', 'Dinah, and saying to her very earnestly, ‘Now, Dinah, tell me the truth:\n', 'Paterson'),
#  (20170114, 'fraud', '‘Off with their heads!’ and the procession moved on, three of the\n', 'Chicago'),
#  (20170114, 'fraud', '‘I couldn’t afford to learn it.’ said the Mock Turtle with a sigh. ‘I\n', 'Lorain'),
#  (20170130, 'fraud', '\n', 'Lancaster'),
#  (20170130, 'fraud', 'a bit.’\n', 'Raleigh'),
#  (20170201, 'fraud', 'close by her.\n', 'Tuscaloosa'),
# ...

# %%
# %sql select * from crime_scene_report where type = 'fraud' and city = 'Jackson'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(20170214, 'fraud', '‘Please come back and finish your story!’ Alice called after it; and the\n', 'Jackson'),
#  (20170527, 'fraud', '\n', 'Jackson')]

# %%
# %sql select * from crime_scene_report where city = 'Jackson' or city = 'Portland'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(20170106, 'blackmail', 'CHAPTER X. The Lobster Quadrille\n', 'Jackson'),
#  (20170208, 'fraud', 'growl, ‘the world would go round a deal faster than it does.’\n', 'Portland'),
#  (20170214, 'fraud', '‘Please come back and finish your story!’ Alice called after it; and the\n', 'Jackson'),
#  (20170303, 'assault', 'her: she gave a little scream, half of fright and half of anger, and\n', 'Portland'),
#  (20170527, 'fraud', '\n', 'Jackson'),
#  (20170604, 'assault', 'it to make it stop.\n', 'Portland'),
#  (20170926, 'smuggling', 'feebly stretching out one paw, trying to touch her. ‘Poor little thing!’\n', 'Jackson'),
#  (20180309, 'theft', 'authority over Alice.\n', 'Jackson'),
#  (20180320, 'smuggling', '‘Stand up and repeat “‘TIS THE VOICE OF THE SLUGGARD,”’ said the\n', 'Portland')]

# %%
# %sql select * from crime_scene_report where city like 'J%'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(20170106, 'blackmail', 'CHAPTER X. The Lobster Quadrille\n', 'Jackson'),
#  (20170108, 'murder', '       HEARTHRUG,\n', 'Jacksonville'),
#  (20170115, 'assault', '‘Nothing WHATEVER?’ persisted the King.\n', 'Jersey City'),
#  (20170207, 'arson', '\n', 'Jefferson'),
#  (20170214, 'fraud', '‘Please come back and finish your story!’ Alice called after it; and the\n', 'Jackson'),
#  (20170222, 'fraud', 'could get away without being seen, when she noticed a curious appearance\n', 'Jersey City'),
#  (20170319, 'theft', '\n', 'Joliet'),
#  (20170420, 'assault', '‘I don’t see,’ said the Caterpillar.\n', 'Johnson City'),
#  (20170509, 'robbery', '\n', 'Johnson City'),
#  (20170519, 'murder', 'The Duchess took her choice, and was gone in a moment.\n', 'Jersey City'),
#  (20170527, 'fraud', '\n', 'Jackson'),
#  (20170607, 'bribery', '\n', 'Joliet'),
# ...

# %%
# %sql select * from crime_scene_report where city like '%son'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(20170106, 'blackmail', 'CHAPTER X. The Lobster Quadrille\n', 'Jackson'),
#  (20170113, 'fraud', 'Dinah, and saying to her very earnestly, ‘Now, Dinah, tell me the truth:\n', 'Paterson'),
#  (20170129, 'blackmail', '‘Call the first witness,’ said the King; and the White Rabbit blew three\n', 'Paterson'),
#  (20170207, 'arson', '\n', 'Jefferson'),
#  (20170214, 'fraud', '‘Please come back and finish your story!’ Alice called after it; and the\n', 'Jackson'),
#  (20170220, 'murder', 'knocking, and hurried upstairs, in great fear lest she should meet the\n', 'Madison'),
#  (20170330, 'murder', '‘I don’t know where Dinn may be,’ said the Mock Turtle, ‘but if you’ve\n', 'Paterson'),
#  (20170408, 'murder', '\n', 'Madison'),
#  (20170520, 'robbery', '‘Then the Dormouse shall!’ they both cried. ‘Wake up, Dormouse!’ And\n', 'Madison'),
#  (20170527, 'fraud', '\n', 'Jackson'),
# ...

# %%
# %sql select * from crime_scene_report where city like 'J%n'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(20170106, 'blackmail', 'CHAPTER X. The Lobster Quadrille\n', 'Jackson'),
#  (20170207, 'arson', '\n', 'Jefferson'),
#  (20170214, 'fraud', '‘Please come back and finish your story!’ Alice called after it; and the\n', 'Jackson'),
#  (20170527, 'fraud', '\n', 'Jackson'),
#  (20170728, 'robbery', 'children she knew, who might do very well as pigs, and was just saying\n', 'Jefferson'),
#  (20170926, 'smuggling', 'feebly stretching out one paw, trying to touch her. ‘Poor little thing!’\n', 'Jackson'),
#  (20180302, 'assault', '    Involved in this affair,\n', 'Jefferson'),
#  (20180309, 'theft', 'authority over Alice.\n', 'Jackson')]

# %%
# %sql select distinct city from crime_scene_report where city between 'W%' and 'Z%'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('Wilmington',),
#  ('Waterbury',),
#  ('West Valley City',),
#  ('Winter Haven',),
#  ('Youngstown',),
#  ('Wichita',),
#  ('West Covina',),
#  ('Yakima',),
#  ('Washington',),
#  ('Winston',),
#  ('Westminster',),
#  ('Waco',),
#  ('Yonkers',),
#  ('Warren',),
#  ('Worcester',),
#  ('Waterloo',),
#  ('York',)]

# %%
# %sql select * from crime_scene_report where date like '2017_106'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(20170106, 'blackmail', 'rather sharply; ‘I advise you to leave off this minute!’ She generally\n', 'Lewisville'),
#  (20170106, 'blackmail', 'CHAPTER X. The Lobster Quadrille\n', 'Jackson'),
#  (20170106, 'theft', '‘Of course it is,’ said the Duchess, who seemed ready to agree to\n', 'High Point'),
#  (20171106, 'robbery', 'nearer, Alice could hear him sighing as if his heart would break. She\n', 'Myrtle Beach'),
#  (20171106, 'murder', '   Yet you balanced an eel on the end of your nose--\n', 'Charleston'),
#  (20171106, 'assault', 'Queen, who was reading the list of singers.\n', 'Oklahoma City')]

# %%
# %sql select distinct city from crime_scene_report where upper(city) = 'JACKSON'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('Jackson',)]

# %%
# %sql select distinct city from crime_scene_report where lower(city) = 'jackson'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('Jackson',)]

# %%
# %sql select city, count(city) from crime_scene_report where city like 'J%' group by city having count(city) > 3
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('Jackson', 5), ('Jersey City', 8), ('Joliet', 4)]

# %%
# %sql select person.name, annual_income from income join person on income.ssn = person.ssn where annual_income > 450000
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('Claudio Carlan', 473100),
#  ('Felice Prudden', 486600),
#  ('Buena Cosimini', 475700),
#  ('Dianna Eyster', 476300),
#  ('Numbers Cranker', 498500),
#  ('Truman Haaker', 489800)]

# %%
# %sql select name, annual_income as income, gender, eye_color as eyes, hair_color as hair from income i join person p on i.ssn = p.ssn join drivers_license dl on p.license_id = dl.id where annual_income > 450000
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('Claudio Carlan', 473100, 'male', 'black', 'brown'),
#  ('Felice Prudden', 486600, 'female', 'green', 'green'),
#  ('Buena Cosimini', 475700, 'female', 'brown', 'blonde'),
#  ('Dianna Eyster', 476300, 'female', 'brown', 'black'),
#  ('Numbers Cranker', 498500, 'male', 'brown', 'green'),
#  ('Truman Haaker', 489800, 'male', 'brown', 'grey')]

# %%
# %sql select * from crime_scene_report where type = 'murder' and city = 'SQL City'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(20180215, 'murder', 'REDACTED REDACTED REDACTED', 'SQL City'),
#  (20180215, 'murder', 'Someone killed the guard! He took an arrow to the knee!', 'SQL City'),
#  (20180115, 'murder', 'Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".', 'SQL City')]

# %%
# %sql select * from person where address_street_name = 'Northwestern Dr' order by address_number desc limit 1
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(14887, 'Morty Schapiro', 118009, 4919, 'Northwestern Dr', '111564949')]

# %%
# %sql select * from person where name like '%Annabel%' and address_street_name = 'Franklin Ave'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(16371, 'Annabel Miller', 490173, 103, 'Franklin Ave', '318771143')]

# %%
# %sql select person.name, interview.transcript from person join interview on person.id = interview.person_id where person.id = 14887 or person.id = 16371
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('Morty Schapiro', 'I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".'),
#  ('Annabel Miller', 'I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.')]

# %%
# %sql select * from get_fit_now_member
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('NL318', 65076, 'Everette Koepke', 20170926, 'gold'),
#  ('AOE21', 39426, 'Noe Locascio', 20171005, 'regular'),
#  ('2PN28', 63823, 'Jeromy Heitschmidt', 20180215, 'silver'),
#  ('0YJ24', 80651, 'Waneta Wellard', 20171206, 'gold'),
#  ('3A08L', 32858, 'Mei Bianchin', 20170401, 'silver'),
#  ('6W6I2', 69510, 'Paris Accurso', 20170613, 'regular'),
#  ('5Y28Y', 15218, 'Millicent Yessios', 20180205, 'gold'),
#  ('156A7', 79701, 'Marcelino Leard', 20180428, 'silver'),
#  ('A5N3S', 24541, 'Mary Cameron', 20170501, 'gold'),
#  ('X0643', 15247, 'Shondra Ledlow', 20170521, 'silver'),
#  ('8T75D', 86040, 'Shani Mcclard', 20170430, 'silver'),
#  ('R440Q', 37694, 'Jan Louthan', 20170606, 'silver'),
#  ('R4J4S', 13703, 'Lien Yasin', 20170414, 'gold'),
#  ('K055L', 60785, 'Latisha Larzazs', 20170503, 'regular'),
#  ('338FV', 66842, 'Susanne Dubicki', 20170719, 'gold'),
#  ('401Y4', 80191, 'Gary Hanohano', 20170627, 'regular'),
# ...

# %%
# %sql select * from get_fit_now_member where id like '48Z%' and membership_status = 'gold'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('48Z7A', 28819, 'Joe Germuska', 20160305, 'gold'),
#  ('48Z55', 67318, 'Jeremy Bowers', 20160101, 'gold')]

# %%
# %sql select * from drivers_license where plate_number like '%H42W%'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(183779, 21, 65, 'blue', 'blonde', 'female', 'H42W0X', 'Toyota', 'Prius'),
#  (423327, 30, 70, 'brown', 'brown', 'male', '0H42W2', 'Chevrolet', 'Spark LS'),
#  (664760, 21, 71, 'black', 'black', 'male', '4H42WR', 'Nissan', 'Altima')]

# %%
# %sql select get_fit_now_member.person_id, person.license_id from get_fit_now_member join person on person.id = get_fit_now_member.person_id where (person_id = 28819 or person_id = 67318) and (license_id = 183779 or license_id = 423327 or license_id = 664760)
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(67318, 423327)]

# %%
# %sql select * from person where license_id = 423327
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(67318, 'Jeremy Bowers', 423327, 530, 'Washington Pl, Apt 3A', '871539279')]

# %%
# %sql insert into solution values (1, 'Jeremy Bowers')
# %sql select value from solution
# Out:
#  * sqlite:///sql-murder-mystery.db
# 1 rows affected.
#  * sqlite:///sql-murder-mystery.db
# Done.
# [("Congrats, you found the murderer! But wait, there's more... If you think you're up for a challenge, try querying the interview transcript of the murd ... (88 characters truncated) ... r SQL skills, try to complete this final step with no more than 2 queries. Use this same INSERT statement with your new suspect to check your answer.",)]

# %%
# %sql select person.name, interview.transcript from person join interview on person.id = interview.person_id where person.id = 67318
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('Jeremy Bowers', 'I was hired by a woman with a lot of money. I don\'t know her name but I know she\'s around 5\'5" (65") or 5\'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n')]

# %%
# %sql select * from drivers_license where (height = '65' or height = '67') and gender = 'female' and hair_color = 'red' and car_make = 'Tesla' and car_model = 'Model S'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(918773, 48, 65, 'black', 'red', 'female', '917UU3', 'Tesla', 'Model S')]

# %%
# %sql select * from person where license_id = '918773'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(78881, 'Red Korb', 918773, 107, 'Camerata Dr', '961388910')]

# %%
# %sql select * from income where ssn = '961388910'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('961388910', 278000)]

# %%
# %sql select * from facebook_event_checkin where person_id = 78881 and event_name like '%SQL Symphony Concert%' and date like '201712%'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# []

# %%
# %sql select person.name, interview.transcript from person join interview on person.id = interview.person_id where person.id = 78881
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# []

# %%
# %sql select * from facebook_event_checkin where event_name like '%SQL Symphony Concert%' and date like '201712%'
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(62596, 1143, 'SQL Symphony Concert', 20171225),
#  (19260, 1143, 'SQL Symphony Concert', 20171214),
#  (58898, 1143, 'SQL Symphony Concert', 20171220),
#  (69699, 1143, 'SQL Symphony Concert', 20171214),
#  (19292, 1143, 'SQL Symphony Concert', 20171213),
#  (43366, 1143, 'SQL Symphony Concert', 20171207),
#  (92343, 1143, 'SQL Symphony Concert', 20171212),
#  (28582, 1143, 'SQL Symphony Concert', 20171220),
#  (28582, 1143, 'SQL Symphony Concert', 20171215),
#  (81526, 1143, 'SQL Symphony Concert', 20171202),
#  (24397, 1143, 'SQL Symphony Concert', 20171208),
#  (11173, 1143, 'SQL Symphony Concert', 20171223),
#  (79312, 1143, 'SQL Symphony Concert', 20171203),
#  (69325, 1143, 'SQL Symphony Concert', 20171206),
#  (24556, 1143, 'SQL Symphony Concert', 20171207),
#  (24556, 1143, 'SQL Symphony Concert', 20171221),
#  (24556, 1143, 'SQL Symphony Concert', 20171224),
#  (99716, 1143, 'SQL Symphony Concert', 20171206),
# ...

# %%
# %sql select person_id, count(person_id) from facebook_event_checkin where event_name like '%SQL Symphony Concert%' and date like '201712%' group by person_id having count(person_id) = 3
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(24556, 3), (99716, 3)]

# %%
# %sql select * from person where id = 24556 or id = 99716
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(24556, 'Bryan Pardo', 101191, 703, 'Machine Ln', '816663882'),
#  (99716, 'Miranda Priestly', 202298, 1883, 'Golden Ave', '987756388')]

# %%
# %sql select * from income where ssn = 987756388
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('987756388', 310000)]

# %%
# %sql select * from drivers_license where id = 202298
# Out:
#  * sqlite:///sql-murder-mystery.db
# Done.
# [(202298, 68, 66, 'green', 'red', 'female', '500123', 'Tesla', 'Model S')]

# %%
# %sql insert into solution values (1, 'Miranda Priestly')
# %sql select value from solution
# Out:
#  * sqlite:///sql-murder-mystery.db
# 1 rows affected.
#  * sqlite:///sql-murder-mystery.db
# Done.
# [('Congrats, you found the brains behind the murder! Everyone in SQL City hails you as the greatest SQL detective of all time. Time to break out the champagne!',)]
